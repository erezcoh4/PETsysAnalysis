# %% [markdown]
# # Why do we get negative QDC values??

# %%
import matplotlib.pyplot as plt
import sys; 
sys.path.insert(0, '/Users/erezcohen/Desktop/Software/mySoftware/Python/'); 
from plot_tools import *;
from my_data_analysis_tools import *;
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %%
Q_highest_gain = pd.read_csv('/Users/erezcohen/Desktop/data/PETsys/BoxSi_proto2.1/vth_2PE/data_with_highest_gain_20_minutes_Q.csv')
Q_default_gain = pd.read_csv('/Users/erezcohen/Desktop/data/PETsys/BoxSi_proto2.1/vth_2PE/data_with_default_gain_20_minutes_Q.csv')

# %%
bins = np.linspace(-20,200,60)
fig,ax=plt.subplots(figsize=(9,6))

hist,edges = np.histogram(Q_highest_gain['Qtot[a.u.]'],bins=bins,density=True);
centers = (edges[1:]+edges[:-1])/2
plt.step(centers,hist,where='mid',label='channel.att=0b100')
hist,edges = np.histogram(Q_default_gain['Qtot[a.u.]'],bins=bins,density=True);
plt.step(centers,hist,where='mid',label='channel.att=0b001')

set_axes(ax,'$\sum_{i=1}^{N_{SiPMs}} Q_{i} $ [DAC units]','frequency of events',do_add_grid=True,do_add_legend=True);
