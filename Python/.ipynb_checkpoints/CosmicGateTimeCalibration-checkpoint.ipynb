# %% [markdown]
# # calibrate cosmic gate timing
# Nov-19, 2020

# %%
import sys; 
sys.path.insert(0, '/Users/erezcohen/Desktop/PETsys/Software/analysis/Python'); 
sys.path.insert(0, '/Users/erezcohen/Desktop/PETsys/Software/PETsysAnalysis/Python'); 
from PETsys_analysis_tools import *;
# %config InlineBackend.figure_format = 'retina'

# %%
sec = 1.e12
nanosec = sec*1e-9
microsec = sec*1e-6
milisec = sec*1e-3
event_timewindow = 100*milisec;

# %%
filepath = '/Users/erezcohen/Desktop/data/PETsys/DuSi/TAU_60cm_scintillator_Nov19_2020/'
filename = 'cosmic_with_trigger_-300nsdelay_th_e8_100sec_single.dat'
cosmic = pd.read_csv(filepath+filename,delimiter='\t',names=['time','charge','channel'])

cosmic_trigg = cosmic[cosmic.channel==4128]
cosmic_scint = cosmic[cosmic.channel!=4128]

print len(cosmic_scint),'SiPM fires which are not in cosmic trigger'
print len(cosmic_trigg),'cosmic trigger events'
# cosmic
# Out:
# 1106 SiPM fires which are not in cosmic trigger
# 6 cosmic trigger events

# %%
# find cosmic events
# group events of SiPM fired within a narrow timewindow 
cosmic_events = dict()

scint_t = np.array(cosmic_scint.time);
scint_dt = np.concatenate([[0],np.diff(scint_t)])
scint_ch = np.array(cosmic_scint.channel);
scint_q = np.array(cosmic_scint.charge);


event_idx = 0;
event_t,event_dt,event_ch,event_q = [],[],[],[]
event_t_R,event_ch_R,event_q_R,event_t_L,event_ch_L,event_q_L = [],[],[],[],[],[]
event_NSiPMs = 0

i = 0
while i < len(scint_t)-1:
    t = scint_t[i]
    dt = scint_dt[i]
    ch = scint_ch[i]
    q = scint_q[i]
#     print i,t,dt

    if np.abs(dt)<event_timewindow:
        event_t.append(t)
        event_dt.append(dt)
        event_ch.append(ch)
        event_q.append(q)        
        event_NSiPMs += 1
        # R/L
        if (64*6<=ch) and (ch<64*7):
            event_t_R.append(t)
            event_ch_R.append(ch)
            event_q_R.append(q)        
        elif (64*9<=ch) and (ch<64*10):
            event_t_L.append(t)
            event_ch_L.append(ch)
            event_q_L.append(q)        
        # step
        i = i+1
        
    else:
        # save event if number of SiPMs that fired is greater than 1
        if event_NSiPMs>0:
            event = dict({  'ch':event_ch,'q':event_q,'t':event_t,
                            'dt':event_dt,'NSiPMs':event_NSiPMs,
                            'ch_R':event_ch_R,'q_R':event_q_R,'t_R':event_t_R,
                            'ch_L':event_ch_L,'q_L':event_q_L,'t_L':event_t_L})
            event['event time'] = np.min(event_t);
            cosmic_events[event_idx] = event
            
            print 'event',event_idx,'at ',event['event time'],',',len(event_ch_R),'right SiPMs,',len(event_ch_L),'left SiPMs'
            print event['ch_R'],event['ch_L']
            event_idx += 1
            # go back one step to record also the line we are standing on
            #             i = i-1    
            event_t,event_dt,event_ch,event_q = [],[],[],[]
            event_t_R,event_ch_R,event_q_R,event_t_L,event_ch_L,event_q_L = [],[],[],[],[],[]
            event_NSiPMs = 0
        # step
        i = i+1
# Out:
# event 0 at  1453864386328 , 0 right SiPMs, 1 left SiPMs
# [] [623]
# event 1 at  2132784854106 , 5 right SiPMs, 3 left SiPMs
# [393, 384, 395, 422, 424] [592, 614, 633]
# event 2 at  2451583648323 , 1 right SiPMs, 2 left SiPMs
# [399] [594, 619]
# event 45 at  39198479991375 , 0 right SiPMs, 4 left SiPMs
# [] [628, 623, 617, 619]
# event 46 at  41429627943255 , 5 right SiPMs, 6 left SiPMs
# [425, 424, 393, 412, 440] [581, 615, 639, 619, 611, 610]
# event 47 at  42134423717903 , 1 right SiPMs, 0 left SiPMs
# [440] []
# event 48 at  45370314911397 , 1 right SiPMs, 1 left SiPMs
# [424] [619]
# event 49 at  45951453645113 , 0 right SiPMs, 1 left SiPMs
# [] [633]
# event 50 at  46406653089854 , 1 right SiPMs, 0 left SiPMs
# [440] []
# event 51 at  47663620994760 , 0 right SiPMs, 4 left SiPMs
# [] [619, 621, 639, 628]
# event 52 at  48133196159728 , 1 right SiPMs, 4 left SiPMs
# [440] [620, 592, 609, 577]
# event 53 at  50296861802899 , 2 right SiPMs, 0 left SiPMs
# [440, 440] []
# event 54 at  50856225308464 , 1 right SiPMs, 0 left SiPMs
# [440] []
# event 55 at  51485891673967 , 17 right SiPMs, 26 left SiPMs
# [405, 412, 387, 406, 418, 388, 432, 399, 409, 417, 425, 436, 391, 415, 396, 424, 446] [609, 621, 630, 633, 577, 586, 592, 611, 620, 631, 639, 618, 610, 625, 601, 617, 628, 594, 623, 598, 585, 615, 619, 627, 581, 595]
# event 56 at  51755088559452 , 13 right SiPMs, 7 left SiPMs
# [428, 390, 434, 407, 391, 436, 400, 409, 425, 413, 387, 427, 384] [623, 626, 588, 618, 633, 594, 628]
# event 57 at  52312795277566 , 1 right SiPMs, 0 left SiPMs
# [440] []
# event 58 at  55511803026141 , 2 right SiPMs, 9 left SiPMs
# [427, 424] [619, 621, 628, 618, 594, 633, 630, 620, 596]
# event 59 at  58082690059335 , 6 right SiPMs, 6 left SiPMs
# [417, 402, 425, 413, 440, 440] [631, 620, 609, 639, 618, 577]
# event 60 at  58927733855104 , 5 right SiPMs, 2 left SiPMs
# [440, 399, 412, 446, 397] [598, 631]
# event 61 at  59511359986758 , 0 right SiPMs, 2 left SiPMs
# [] [614, 619]
# event 62 at  64567000620772 , 1 right SiPMs, 1 left SiPMs
# [400] [628]
# event 63 at  67213000260810 , 2 right SiPMs, 7 left SiPMs
# [424, 425] [630, 620, 609, 628, 623, 619, 594]
# event 64 at  69394621366978 , 1 right SiPMs, 9 left SiPMs
# [393] [618, 636, 627, 623, 615, 598, 617, 609, 586]
# event 65 at  70539969461011 , 2 right SiPMs, 12 left SiPMs
# [400, 425] [623, 593, 639, 625, 618, 615, 598, 633, 581, 628, 630, 596]
# event 66 at  70981344627074 , 1 right SiPMs, 0 left SiPMs
# [440] []
# event 67 at  72682212184792 , 5 right SiPMs, 5 left SiPMs
# [387, 388, 393, 412, 425] [581, 623, 609, 628, 610]
# event 68 at  72933070447670 , 1 right SiPMs, 0 left SiPMs
# [440] []
# event 69 at  73986814612432 , 3 right SiPMs, 0 left SiPMs
# [440, 440, 440] []
# event 70 at  76762514521838 , 3 right SiPMs, 2 left SiPMs
# [440, 440, 395] [594, 623]
# event 71 at  78408893668031 , 1 right SiPMs, 0 left SiPMs
# [440] []
# event 72 at  78582260714922 , 1 right SiPMs, 1 left SiPMs
# [440] [619]
# event 73 at  82675159770123 , 3 right SiPMs, 4 left SiPMs
# [405, 424, 440] [594, 636, 619, 618]
# event 74 at  84568881905755 , 0 right SiPMs, 2 left SiPMs
# [] [581, 625]
# event 75 at  87961485982852 , 1 right SiPMs, 4 left SiPMs
# [440] [636, 610, 630, 619]
# event 76 at  89428275168594 , 1 right SiPMs, 6 left SiPMs
# [425] [622, 621, 639, 623, 628, 620]
# event 77 at  90253730241739 , 1 right SiPMs, 0 left SiPMs
# [440] []
# event 78 at  90883172940685 , 0 right SiPMs, 4 left SiPMs
# [] [610, 577, 623, 639]
# event 79 at  91370801749188 , 1 right SiPMs, 2 left SiPMs
# [395] [581, 639]
# event 80 at  91547386354178 , 0 right SiPMs, 1 left SiPMs
# [] [630]
# event 81 at  92352924175628 , 0 right SiPMs, 1 left SiPMs
# [] [581]
# event 82 at  95813705457240 , 0 right SiPMs, 2 left SiPMs
# [] [628, 619]
# event 83 at  96244093582365 , 1 right SiPMs, 0 left SiPMs
# [440] []
# event 84 at  98785104967318 , 0 right SiPMs, 1 left SiPMs
# [] [615]

# %%
# distribution of time intervals between cosmic events
cosmic_event_dt,cosmic_event_time = [],[]

for eventIdx in range(len(cosmic_events)):
    cosmic_event_time.append( cosmic_events[eventIdx]['event time'])
cosmic_event_time = np.array(cosmic_event_time)

for eventIdx in range(len(cosmic_events)-1):
    cosmic_event_dt.append( cosmic_events[eventIdx+1]['event time'] - cosmic_events[eventIdx]['event time'] )    
cosmic_event_dt = np.array(cosmic_event_dt)
cosmic_event_dt/nanosec
# Out:
# array([6.78920468e+08, 3.18798794e+08, 5.64797505e+08, 7.36789067e+08,
#        1.30999473e+08, 5.85633178e+08, 1.04480632e+09, 4.48193653e+08,
#        2.06682485e+09, 3.99935067e+09, 1.71631494e+09, 6.12899535e+08,
#        4.01854642e+08, 5.17513282e+08, 7.68307570e+08, 6.63966029e+08,
#        1.11093325e+09, 1.70001630e+09, 2.75939747e+08, 3.98282301e+08,
#        1.22102376e+09, 1.45494650e+09, 1.96181787e+09, 1.63899610e+08,
#        9.12645620e+08, 6.49551623e+08, 8.39691773e+08, 1.14424305e+09,
#        2.20859406e+09, 2.89168962e+08, 5.15579607e+08, 4.89309701e+08,
#        2.54401708e+08, 2.73814297e+08, 6.77813143e+08, 3.67138142e+08,
#        4.91941667e+08, 1.45647526e+09, 2.33395655e+08, 3.61598348e+08,
#        1.51350336e+09, 3.77271099e+08, 6.04164166e+08, 3.31292991e+08,
#        2.10192057e+08, 2.23114795e+09, 7.04795775e+08, 3.23589119e+09,
#        5.81138734e+08, 4.55199445e+08, 1.25696790e+09, 4.69575165e+08,
#        2.16366564e+09, 5.59363506e+08, 6.29666366e+08, 2.69196885e+08,
#        5.57706718e+08, 3.19900775e+09, 2.57088703e+09, 8.45043796e+08,
#        5.83626132e+08, 5.05564063e+09, 2.64599964e+09, 2.18162111e+09,
#        1.14534809e+09, 4.41375166e+08, 1.70086756e+09, 2.50858263e+08,
#        1.05374416e+09, 2.77569991e+09, 1.64637915e+09, 1.73367047e+08,
#        4.09289906e+09, 1.89372214e+09, 3.39260408e+09, 1.46678919e+09,
#        8.25455073e+08, 6.29442699e+08, 4.87628809e+08, 1.76584605e+08,
#        8.05537821e+08, 3.46078128e+09, 4.30388125e+08, 2.54101138e+09])

# %%
from mpl_toolkits.axes_grid.inset_locator import inset_axes
fig=plt.figure(figsize=(12,6)); 
ax = fig.add_subplot(1,1,1); 
plt.hist( cosmic_event_dt/sec , bins=np.linspace(0,6,30), edgecolor='k');
set_axes(ax=ax,x_label='$\delta t$ between consequent cosmic events [sec]', y_label='number of events',
         fontsize=17,do_add_grid=True,do_add_legend=False, ylim=(0,10));


inset_axes = inset_axes(ax, 
                    width="50%", # of parent_bbox
                    height=2.5, # height : 1 inch
                    loc=1)
# n, bins, patches = plt.hist(s, 400, normed=1)
#plt.title('Probability')
# plt.xticks([])
# plt.yticks([])
plt.hist( cosmic_event_dt/milisec , bins=np.linspace(0,1000,100));
set_axes(ax=inset_axes,x_label='$\delta t$ [ms]', y_label='',remove_ticks_y=True,
         fontsize=17,do_add_grid=True,do_add_legend=False);

# ax.set_xscale('log')

# %%
fig=plt.figure(figsize=(15,7)); 
ax = fig.add_subplot(1,1,1)

time = np.array(cosmic_trigg.time)
charge = np.array(cosmic_trigg.charge);
for i in range(len(time)):
    t = time[i];
    q = charge[i];
    if q==1:color='b'
    else: color='g'
    plt.plot( [t/sec,t/sec] , [0,q*5] , color, linewidth=2)
    
plt.plot( scint_t/sec, scint_q ,'r.')
set_axes(ax=ax,
         x_label='time [sec]', y_label='charge [a.u.]', 
         fontsize=17,do_add_grid=True,do_add_legend=False,ylim=(-0.5,5));

# add events
for event in cosmic_events.values():
     plt.plot( [event['event time']/sec,event['event time']/sec] , [-1,5] , 'k' , linewidth=4, alpha=0.1)
plt.tight_layout()

# %% [markdown]
# ## now open a time window around each cosmic event triggered by the finger scintllators, and compute the time resolution of this event

# %%
def get_all_differences_R_L(t_L,t_R):#{
    # compute time differences between all combinations of t_L and t_R
    mesh = np.array(np.meshgrid(t_R,t_L))
    combinations = mesh.T.reshape(-1, 2)
    dt = np.diff(combinations)
    return dt
#}

# %%
print 'cosmic triggered events at', cosmic_trigg_time
print 
finger_trig_time_window = 200*milisec
cosmic_trigg_time = np.array(cosmic_trigg[cosmic_trigg.charge==1].time)
for scintIdx in range(len(cosmic_event_time)):
    t_event = cosmic_event_time[scintIdx]
    #     print 'cosmic event at time ',t_event
    
    for cosmicTrigIdx in range(len(cosmic_trigg_time)):
        t_trig = cosmic_trigg_time[cosmicTrigIdx]
        #         print t_trig, np.abs(t_event - t_trig)
        if (np.abs(t_event - t_trig)<finger_trig_time_window):
            event = cosmic_events[scintIdx]
            print 'cosmic event at time',t_event/sec,'sec triggered by finger scintillators'
            q_L, q_R, t_L, t_R = event['q_L'],event['q_R'],event['t_L'],event['t_R']
            
            dt = get_all_differences_R_L(t_L,t_R)            
            event['dt'] = dt
            event['mean(dt)'] = np.mean(dt)
            event['NSiPMs left'] = len(q_L)
            event['NSiPMs right'] = len(q_R)
            event['mean NSiPMs'] = (len(q_L)+len(q_R))/2.
            event['Qtot'] = np.sum(q_L) + np.sum(q_R)
            event['Qavg'] = event['Qtot']/(len(q_L)+len(q_R))

            cosmic_events[scintIdx] = event
            print event['mean(dt)'],event['Qtot'],event['mean NSiPMs']
#             print  ch_L, ch_R

# To continue here, need to: 
# (1) accumulate many events
# (2) verify that a time window of 100 ms is reasonable and not too large....
# (3) compute monets of dt distribution, as a function of Qtot
# Out:
# cosmic triggered events at [17677344436250 76927612331250 99715504147500]
#
# cosmic event at time 17.820767610753 sec triggered by finger scintillators
# 27162902982.555557 0.4553900000000005 5.0
# cosmic event at time 76.762514521838 sec triggered by finger scintillators
# 24710578894.0 0.9941290000000004 2.5
